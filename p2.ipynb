# %%
a=10
b=20
c="Hetvi"
d="Hetvi Patel"

print(a<b)
print(a>b)
print(a==b)
print(a>=b)
print(a<=b)
print(a!=b)


print(a and b)
print(a or b)
print(not b)

print(c in d)
print(c not in d)
# Out:
# True
# False
# False
# False
# True
# True
# 20
# 10
# False
# True
# False

# %%
a=input("Enter character :")
print(ord(a))
# Out:
# Enter character : a
# 97

# %%
a= int(input("Enter ascii no:"))
print(chr(a))
# Out:
# Enter ascii no: 65
# A
