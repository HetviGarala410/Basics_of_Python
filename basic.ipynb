# %%
print("hyy")
print("hi")
print("good morning")
# Out:
# hyy
# hi
# good morning

# %%
print("hyy \n hi \n good morning")
# Out:
# hyy
#  hi
#  good morning

# %%
name="diya"
age=19
height=5.0
print("my name is ",name, "age is",age,"my height is",height)
# Out:
# my name is  diya age is 19 my height is 5.0

# %%
name="diya"
print(type(name))
age=19
height=5.0
print(f"my name is,{name} age is{age},my height is {height}")
# Out:
# <class 'str'>
# my name is,diya age is19,my height is 5.0

# %%
a=3
b=2
print("the sum is ",a+b)
# Out:
# the sum is  5

# %%
a=3
b=2
print("the sub is ",a-b)
# Out:
# the sub is  1

# %%
a=3
b=2
print("the mul is ",a*b)
# Out:
# the mul is  6

# %%
a=3
b=2
print("the power is ",a**b)
# Out:
# the power is  9

# %%
a=3
b=2
print("the doublediv is ",a//b)
# Out:
# the doublediv is  1

# %%
a=3
b=2
print("the modulus is ",a%b)
# Out:
# the modulus is  1
