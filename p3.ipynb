# %%
a=int(input("Enter number 1"))
b=int(input("Enter number 2"))

print("Sum",a+b)
# Out:
# Enter number 1 3
# Enter number 2 4
# Sum 7

# %%
r=int(input("Enter radius:"))
a= 22/7*(r**2)
print("Area:",a)
# Out:
# Enter radius: 10
# Area: 314.2857142857143

# %%
b=int(input("Enter Base:"))
h=int(input("Enter height:"))
a=0.5*b*h
print("Area:",a)
# Out:
# Enter Base: 5
# Enter height: 10
# Area: 25.0

# %%
h=int(input("Enter hour:"))
m=60*h
print("Minute :",m)
s=3600*h
print("second:",s)
# Out:
# Enter hour: 2
# Minute : 120
# second: 7200

# %%
x=int(input("Enter number of days:"))
y=x//360
print("Year:",y)
r=x%360
m=r//30
print("Months:",m)
d=r%30
print("Days:",d)
# Out:
# Enter number of days: 392
# Year: 1
# Months: 1
# Days: 2

# %%
x=int(input("Enter number of seconds:"))
h=x//3600
print("Hours:",h)
r=x%3600
m=r//60
print("Minutes:",m)
s=r%60
print("Seconds:",s)
# Out:
# Enter number of seconds: 3662
# Hours: 1
# Minutes: 1
# Seconds: 2
